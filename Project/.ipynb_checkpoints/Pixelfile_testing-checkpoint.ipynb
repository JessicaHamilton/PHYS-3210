# %%
import numpy as np
import gzip
import matplotlib.pyplot as plt
from astropy.io import fits as fits
from astropy.stats import sigma_clip
import lightkurve as lk
from lightkurve import SFFCorrector
from lightkurve import search_tesscut
import astropy.units as u
from astropy import stats
import time as datetime
from lightkurve import periodogram
from astropy.convolution import Box1DKernel, convolve
from tqdm import tqdm_notebook as tqdm
import numpy.linalg as lin
import scipy.linalg as sclin
from scipy import stats as st
import pandas as pd

from lightkurve import search_targetpixelfile

from scipy import ndimage as nd
import re
plt.rcParams.update({'figure.max_open_warning': 0})
import warnings
warnings.filterwarnings("ignore")

#Import all needed packages

# %%
cd /Users/hamil/Documents/TESSFiles
# Out:
# C:\Users\hamil\Documents\TESSFiles

# %%
tpf1 = search_targetpixelfile('TIC 31273263', sector= 1).download() ###
tpf2 = search_targetpixelfile('TIC 31273263', sector= 2).download() ###
tpf3 = search_targetpixelfile('TIC 31928890', sector= 1).download()
tpf4 = search_targetpixelfile('TIC 31928890', sector= 2).download()
tpf5 = search_targetpixelfile('TIC 31963492', sector= 1).download()

# %%
tpf6 = search_targetpixelfile('TIC 31963492', sector= 2).download()
tpf7 = search_targetpixelfile('TIC 33734375', sector= 1).download()
tpf8 = search_targetpixelfile('TIC 33734375', sector= 2).download()
tpf9 = search_targetpixelfile('TIC 231833061', sector= 1).download() ###
tpf10 = search_targetpixelfile('TIC 231833061', sector= 2).download() ###

# %%
#tpf11 = search_targetpixelfile('TIC 260504147', sector= 1).download()
#tpf12 = search_targetpixelfile('TIC 260504147', sector= 2).download()
#tpf13 = search_targetpixelfile('TIC 370324073', sector= 1).download()
tpf14 = search_targetpixelfile('TIC 425906447', sector= 1).download()
tpf15 = search_targetpixelfile('TIC 425906447', sector= 2).download()

# %%
tpf16 = search_targetpixelfile('TIC 33767523', sector= 1).download()
tpf17 = search_targetpixelfile('TIC 33767523', sector= 2).download()
tpf18 = search_targetpixelfile('TIC 179371765', sector= 1).download()
tpf19 = search_targetpixelfile('TIC 179371765', sector= 2).download()
tpf20 = search_targetpixelfile('TIC 179985566', sector= 2).download() ###

# %%
tpf21 = search_targetpixelfile('TIC 270411008', sector= 2).download() ###
tpf22 = search_targetpixelfile('TIC 271975434', sector= 1).download()
tpf23 = search_targetpixelfile('TIC 271975434', sector= 2).download()

# %%
aper1 = tpf1.create_threshold_mask()
tpf1.plot(aperture_mask=aper1)
raw_lc1 = tpf1.to_lightcurve(aperture_mask=aper1)
raw_lc1.plot()

regressors1 = tpf1.flux[:, ~aper1]
regressors1.shape
dm1 = lk.DesignMatrix(regressors1, name='regressors')
dm1 = dm1.pca(5)

plt.plot(tpf1.time, dm1.values + np.arange(5)*0.2, '.')
dm1.plot()

# %%
corrector1 = lk.RegressionCorrector(raw_lc1)
corrected_lc1 = corrector1.correct(dm1)
corrected_lc1.plot()

corrector1.diagnose()

model1 = corrector1.model_lc
model1.plot()
model1 -= np.percentile(model1.flux, 5)

corrected_lc1 = raw_lc1 - model1
corrected_lc1.plot()
flux = corrected_lc1.flux
time = corrected_lc1.time
condition = ((time > 1347) & (time < 1350))
flux[condition] = np.median(flux)
lc1 = lk.LightCurve(time,flux).remove_nans().remove_outliers(sigma_lower=3, sigma_upper=3).flatten(window_length=145)

power1 = lc1.to_periodogram(method='lombscargle', normalization="psd")
power1.plot()
power1.plot(scale='log')

# %%
aper2 = tpf2.create_threshold_mask()
tpf2.plot(aperture_mask=aper2)
raw_lc2 = tpf2.to_lightcurve(aperture_mask=aper2)
raw_lc2.plot()

regressors2 = tpf2.flux[:, ~aper2]
regressors2.shape
dm2 = lk.DesignMatrix(regressors2, name='regressors')
dm2 = dm2.pca(5)

plt.plot(tpf2.time, dm2.values + np.arange(5)*0.2, '.')
dm2.plot()

# %%
corrector2 = lk.RegressionCorrector(raw_lc2)
corrected_lc2 = corrector2.correct(dm2)
corrected_lc2.plot()
plt.title('Corrected LC')
corrector2.diagnose()

model2 = corrector2.model_lc
model2.plot()
plt.title('Model LC')
model2 -= np.percentile(model2.flux, 5)

corrected_lc2 = raw_lc2 - model2
corrected_lc2.plot()
plt.title('Corrected - Model LC')
flux2 = corrected_lc2.flux
time2 = corrected_lc2.time
condition = ((time2 > 1347) & (time2 < 1350))
flux2[condition] = np.median(flux2)
lc2 = lk.LightCurve(time2,flux2).remove_nans().remove_outliers(sigma_lower=3, sigma_upper=3).flatten(window_length=145)
lc2.scatter()
power2 = lc2.to_periodogram(method='lombscargle', normalization="psd")
power2.plot()
power2.plot(scale='log')

# %%
combined_lc1 = lc1.append(lc2)
combined_lc1.scatter()
power_combined = combined_lc1.to_periodogram(method='lombscargle', normalization = 'psd')
power_combined.plot()
power_combined.plot(scale= 'log')

# %%
aper9 = tpf9.create_threshold_mask()
tpf9.plot(aperture_mask=aper9)
raw_lc9 = tpf9.to_lightcurve(aperture_mask=aper9)
raw_lc9.plot()

regressors9 = tpf9.flux[:, ~aper9]
regressors9.shape
dm9 = lk.DesignMatrix(regressors9, name='regressors')
dm9 = dm9.pca(5)
print(dm9)
plt.plot(tpf9.time, dm9.values + np.arange(5)*0.2, '.')
dm9.plot()
# Out:
# regressors DesignMatrix (18104, 5)

# %%
corrector9 = lk.RegressionCorrector(raw_lc9)
corrected_lc9 = corrector9.correct(dm9)
corrected_lc9.plot()
plt.title('Corrected LC')
corrector9.diagnose()

model9 = corrector9.model_lc
model9.plot()
model9 -= np.percentile(model9.flux, 5)
plt.title('Model LC')
corrected_lc9 = raw_lc9 - model9
corrected_lc9.plot()
plt.title('Corrected - Model LC')
flux9 = corrected_lc9.flux
time9 = corrected_lc9.time
condition = ((time9 > 1347) & (time9 < 1350))
flux9[condition] = np.median(flux9)
lc9 = lk.LightCurve(time9,flux9).remove_nans().remove_outliers(sigma_lower=3, sigma_upper=3).flatten(window_length=145)

power9 = lc9.to_periodogram(method='lombscargle', normalization="psd")
power9.plot()
power9.plot(scale='log')

# %%
aper10 = tpf10.create_threshold_mask()
tpf10.plot(aperture_mask=aper10)
raw_lc10 = tpf10.to_lightcurve(aperture_mask=aper10).remove_nans().remove_outliers(sigma_lower=3, sigma_upper=3).flatten(window_length=145)
raw_lc10.plot()
power = raw_lc10.to_periodogram(method='lombscargle', normalization="psd")
power.plot()
power.plot(scale='log')
regressors10 = tpf10.flux[:, ~aper10]
regressors10.shape
dm10 = lk.DesignMatrix(regressors10, name='regressors10')
dm10 = dm10.append_constant().standardize()
print(dm10)
dm10 = dm10.pca(nterms=5)
#plt.plot(tpf10.time, dm10.values + np.arange(5)*0.2, '.')
#dm10.plot()
# Out:
# regressors10 DesignMatrix (18317, 92)

# %%
corrector10 = lk.RegressionCorrector(raw_lc10)
corrected_lc10 = corrector10.correct(dm10)
corrected_lc10.plot()
plt.title('Corrected LC')
corrector10.diagnose()

model10 = corrector10.model_lc
model10.plot()
model10 -= np.percentile(model10.flux, 5)
plt.title('Model LC')
corrected_lc10 = raw_lc10 - model10
corrected_lc10.plot()
plt.title('Corrected - Model LC')
flux10 = corrected_lc10.flux
time10 = corrected_lc10.time
lc10 = lk.LightCurve(time10,flux10).remove_nans().remove_outliers(sigma_lower=3, sigma_upper=3).flatten(window_length=145)

power10 = lc10.to_periodogram(method='lombscargle', normalization="psd")
power10.plot()
power10.plot(scale='log')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-302-3c4dd180679c> in <module>
#       1 corrector10 = lk.RegressionCorrector(raw_lc10)
# ----> 2 corrected_lc10 = corrector10.correct(dm10)
#       3 corrected_lc10.plot()
#       4 plt.title('Corrected LC')
#       5 corrector10.diagnose()
#
# ~\Anaconda3\lib\site-packages\lightkurve\correctors\regressioncorrector.py in correct(self, design_matrix_collection, cadence_mask, sigma, niters, propagate_errors)
#     209                                        prior_mu=self.X.prior_mu,
#     210                                        prior_sigma=self.X.prior_sigma,
# --> 211                                        propagate_errors=propagate_errors)
#     212             residuals = self.lc.flux - np.dot(self.X.values, coefficients)
#     213             cadence_mask &= ~sigma_clip(residuals, sigma=sigma).mask
#
# ...

# %%
aper20 = tpf20.create_threshold_mask()
tpf20.plot(aperture_mask=aper20)
raw_lc20 = tpf20.to_lightcurve(aperture_mask=aper20)
raw_lc20.plot()

regressors20 = tpf20.flux[:, ~aper20]
regressors20.shape
dm20 = lk.DesignMatrix(regressors20, name='regressors')
dm20 = dm20.append_constant().standardize()
#dm20 = dm20.pca(5)

#plt.plot(tpf20.time, dm20.values + np.arange(5)*0.2, '.')
#dm20.plot()

# %%
corrector20 = lk.RegressionCorrector(raw_lc20)
corrected_lc20 = corrector20.correct(dm20)
corrected_lc20.plot()
plt.title('Corrected LC')
corrector20.diagnose()

model20 = corrector20.model_lc
model20.plot()
model20 -= np.percentile(model20.flux, 5)
plt.title('Model LC')
corrected_lc20 = raw_lc20 - model20
corrected_lc20.plot()
plt.title('Corrected - Model LC')
flux20 = corrected_lc20.flux
time20 = corrected_lc20.time
lc20 = lk.LightCurve(time20,flux20).remove_nans().remove_outliers().flatten(window_length=145)

power20 = lc20.to_periodogram(method='lombscargle', normalization="psd")
power20.plot()
power20.plot(scale='log')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-301-3812b805093c> in <module>
#       1 corrector20 = lk.RegressionCorrector(raw_lc20)
# ----> 2 corrected_lc20 = corrector20.correct(dm20)
#       3 corrected_lc20.plot()
#       4 plt.title('Corrected LC')
#       5 corrector20.diagnose()
#
# ~\Anaconda3\lib\site-packages\lightkurve\correctors\regressioncorrector.py in correct(self, design_matrix_collection, cadence_mask, sigma, niters, propagate_errors)
#     209                                        prior_mu=self.X.prior_mu,
#     210                                        prior_sigma=self.X.prior_sigma,
# --> 211                                        propagate_errors=propagate_errors)
#     212             residuals = self.lc.flux - np.dot(self.X.values, coefficients)
#     213             cadence_mask &= ~sigma_clip(residuals, sigma=sigma).mask
#
# ...
